# %%
Imersão Python Aula 2

# %%
import pandas as pd

# %%
tabela = pd.read_excel("/content/Diego[ Imersão Python - Tabela de ações].xlsx", sheet_name="Principal")

tabela.head(15)
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5   PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6   PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7   VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8   MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9   ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
# 10  RDOR3 2024-01-26        27.56          1.43           3.41         -4.17
# ...

# %%
tabela_acoes = pd.read_excel("/content/Diego[ Imersão Python - Tabela de ações].xlsx", sheet_name="Total_de_acoes")
tabela_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
tabela_Ticker = pd.read_excel("/content/Diego[ Imersão Python - Tabela de ações].xlsx", sheet_name="Ticker")
tabela_Ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
tabela_Chat = pd.read_excel("/content/Diego[ Imersão Python - Tabela de ações].xlsx", sheet_name="ChatGPT")
tabela_Chat
# Out:
#         Nome Empresa           Segmento  Idade (em anos)
# 0           Usiminas         Siderurgia               59
# 1      CSN Mineração          Mineração               77
# 2          Petrobras   Energia/Petróleo               68
# 3             Suzano   Papel e Celulose               99
# 4       CPFL Energia            Energia              108
# ..               ...                ...              ...
# 73  Carrefour Brasil             Varejo               45
# 74       Casas Bahia             Varejo               64
# 75          Localiza  Aluguel de Carros               49
# 76               CVC            Turismo               49
# 77               GOL   Transporte Aéreo               20
#
# [78 rows x 3 columns]
